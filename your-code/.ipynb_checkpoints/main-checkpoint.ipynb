# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv("Temp_States.csv")

# %% [markdown]
# #### Print `temp`

# %%
temp.head(10)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
temp.info()
# dos tipos de datos, city y state son objetos de pandas y temperatura flotante
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      object
#  1   State        7 non-null      object
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
NY_rows = temp[temp['State'] == 'New York']
NY_rows
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
NY_rows.mean()
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_1800\35584419.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   NY_rows.mean()
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp_ab_15 = temp[temp['Temperature'] > 15]
temp_ab_15
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp_ab_15['City']
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
ds=temp[(temp['Temperature'] > 15) & (temp['Temperature'] < 20)]
ds
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
temp2 = temp.groupby('State', as_index=False).agg({'Temperature':np.mean})
temp2.rename(columns = {'Temperature':'Temp_mean'}, inplace=True)

temp3 =  temp.groupby('State', as_index=False).agg({'Temperature':np.std})
temp3.rename(columns = {'Temperature':'Temp_std'},inplace=True)

temp2['Temp_std'] = temp3['Temp_std']
temp2
# Out:
#          State  Temp_mean  Temp_std
# 0  Connecticut  15.833333  1.964186
# 1   New Jersey  21.111111  1.571348
# 2     New York  10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee = pd.read_csv("employee.csv")
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.info()
#Years y Salary son enteros, el resto son objetos de pandas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9 non-null      object
#  1   Department  9 non-null      object
#  2   Education   9 non-null      object
#  3   Gender      9 non-null      object
#  4   Title       9 non-null      object
#  5   Years       9 non-null      int64
#  6   Salary      9 non-null      int64
# dtypes: int64(2), object(5)
# memory usage: 632.0+ bytes

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
employee['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
#df.loc[(df.loc[:, 'Personalcare'] >= 70), ['Country', 'Sleep', 'Personalcare', 
                                           #'Friends', 'Shopping', 'Paidwork']]
employee.loc[(employee.loc[:, 'Salary'] == employee['Salary'].min()), 'Name']
# Out:
# 1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[employee['Name']=='David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee.loc[(employee.loc[:, 'Name'] == 'David'), 'Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee[employee['Title']=='associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee.iloc[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[(employee['Title'] == 'associate') & (employee['Salary'] > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
years_sal = employee.groupby('Years', as_index=False).agg({'Salary':np.mean})
years_sal
# Out:
#    Years     Salary
# 0      1  35.000000
# 1      2  38.333333
# 2      3  55.000000
# 3      4  35.000000
# 4      7  60.000000
# 5      8  70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
title_sal = employee.groupby('Title', as_index=False).agg({'Salary':np.mean})
title_sal
# Out:
#        Title     Salary
# 0         VP  70.000000
# 1    analyst  32.500000
# 2  associate  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
for columna in employee._get_numeric_data():
    print(columna)
    print(employee[columna].plot.box())
    plt.show()
    print('--------' * 10)
# Out:
# Years
# AxesSubplot(0.125,0.125;0.775x0.755)
# --------------------------------------------------------------------------------
# Salary
# AxesSubplot(0.125,0.125;0.775x0.755)
# --------------------------------------------------------------------------------

# %%
# print first quartile here
Qs= employee.describe()
print("Q1 Years:", Qs.iloc[4,0]) #df.iloc[0:5, 10:16]
print("Q1 Salary:", Qs.iloc[4,1])
Qs
# Out:
# Q1 Years: 2.0
# Q1 Salary: 35.0
#           Years     Salary
# count  9.000000   9.000000
# mean   4.111111  48.888889
# std    2.803767  16.541194
# min    1.000000  30.000000
# 25%    2.000000  35.000000
# 50%    3.000000  55.000000
# 75%    7.000000  60.000000
# max    8.000000  70.000000

# %%
# print third quartile here
print("Q1 Years:", Qs.iloc[6,0]) #df.iloc[0:5, 10:16]
print("Q1 Salary:", Qs.iloc[6,1])
Qs
# Out:
# Q1 Years: 7.0
# Q1 Salary: 60.0
#           Years     Salary
# count  9.000000   9.000000
# mean   4.111111  48.888889
# std    2.803767  16.541194
# min    1.000000  30.000000
# 25%    2.000000  35.000000
# 50%    3.000000  55.000000
# 75%    7.000000  60.000000
# max    8.000000  70.000000

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
title_gen = employee.groupby('Gender', as_index=False).agg({'Salary':np.mean})
title_gen
#si es diferente
# Out:
#   Gender  Salary
# 0      F    47.5
# 1      M    50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
employee2 = employee.groupby('Department', as_index=False).agg({'Years':np.mean})
employee2.rename(columns = {'Years':'Years_mean'}, inplace=True)

employee2_1 = employee.groupby('Department', as_index=False).agg({'Years':np.min})
employee2_1.rename(columns = {'Years':'Years_min'}, inplace=True)

employee2_2 = employee.groupby('Department', as_index=False).agg({'Years':np.max})
employee2_2.rename(columns = {'Years':'Years_max'}, inplace=True)

employee2['Years_min'] = employee2_1['Years_min']
employee2['Years_max'] = employee2_2['Years_max']

employee3 = employee.groupby('Department', as_index=False).agg({'Salary':np.mean})
employee3.rename(columns = {'Salary':'Salary_mean'}, inplace=True)

employee3_1 = employee.groupby('Department', as_index=False).agg({'Salary':np.min})
employee3_1.rename(columns = {'Salary':'Salary_min'}, inplace=True)

employee3_2 = employee.groupby('Department', as_index=False).agg({'Salary':np.max})
employee3_2.rename(columns = {'Salary':'Salary_max'}, inplace=True)

employee2['Salary_mean'] = employee3['Salary_mean']
employee2['Salary_min'] = employee3_1['Salary_min']
employee2['Salary_max'] = employee3_2['Salary_max']

employee2
# Out:
#   Department  Years_mean  Years_min  Years_max  Salary_mean  Salary_min  \
# 0         HR    4.666667          2          8        45.00          30
# 1         IT    4.500000          1          8        48.75          30
# 2      Sales    2.500000          2          3        55.00          55
#
#    Salary_max
# 0          70
# 1          70
# 2          55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv("Orders.csv")
orders.head(10)
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
# 5           5     536365     22752  2010     12    3     8
# 6           6     536365     21730  2010     12    3     8
# 7           7     536366     22633  2010     12    3     8
# 8           8     536366     22632  2010     12    3     8
# 9           9     536367     84879  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  object
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  object
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  object
#  10  UnitPrice     397924 non-null  float64
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  object
#  13  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB

# %%
# your answer here
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
orders['amount_spent'].mean()
# Out:
# 22.394748504739596

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders['amount_spent'].min()
# Out:
# 0.0

# %%
# your answer here
orders['amount_spent'].max()
# Out:
# 168469.6

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
espana=orders.loc[(orders.loc[:,'Country'] == 'Spain'), ['Country','CustomerID']]
espana
# Out:
#        Country  CustomerID
# 4250     Spain       12557
# 4251     Spain       12557
# 4252     Spain       12557
# 4253     Spain       12557
# 4254     Spain       12557
# ...        ...         ...
# 394733   Spain       17097
# 394734   Spain       17097
# 394735   Spain       17097
# 394736   Spain       17097
# 394737   Spain       17097
#
# [2485 rows x 2 columns]

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
spain=orders[(orders['Country'] == 'Spain')]
len(list(spain['CustomerID'].value_counts()))
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
cus_ab_50 = orders.loc[(orders.loc[:,'Quantity'] > 50),'CustomerID'].unique()
list(cus_ab_50)
# Out:
# [13748,
#  15291,
#  14688,
#  16029,
#  17511,
#  13408,
#  12791,
#  14045,
#  13255,
#  13694,
#  16210,
#  17181,
#  15485,
#  12433,
#  18144,
#  13093,
#  17760,
#  17025,
#  13777,
#  13576,
#  17925,
#  13941,
#  14135,
#  13108,
#  18041,
#  14060,
#  15738,
#  17381,
#  17685,
#  15061,
#  14031,
#  14775,
#  15299,
#  13798,
#  16754,
#  15093,
#  12967,
#  14156,
#  14680,
#  12557,
#  17809,
#  16013,
#  17949,
#  12395,
#  13081,
#  15465,
#  13089,
#  14800,
#  16839,
#  16168,
#  13269,
#  13831,
#  15716,
#  13767,
#  17402,
#  15311,
#  16422,
#  17677,
#  17674,
#  13094,
#  15039,
#  14189,
#  14708,
#  18113,
#  17596,
#  14911,
#  17191,
#  14409,
#  12913,
#  17450,
#  17616,
#  15649,
#  12681,
#  15838,
#  14733,
#  13756,
#  17491,
#  14739,
#  18102,
#  16365,
#  17870,
#  12386,
#  13199,
#  16525,
#  15973,
#  15032,
#  18061,
#  15298,
#  13270,
#  14866,
#  13077,
#  13848,
#  15347,
#  13758,
#  17340,
#  17655,
#  15513,
#  18092,
#  12755,
#  17857,
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
#spain.loc[(spain.loc['Quantity'] > 50),['CustomerID','']]
orders.loc[((orders.loc[:, 'Country'] == 'Spain') & (orders.loc[:, 'Quantity'] > 50)),['CustomerID','Country','Description','Quantity']]
# Out:
#         CustomerID Country                          Description  Quantity
# 4250         12557   Spain              lunch bag suki  design         70
# 4251         12557   Spain              lunch bag pink polkadot       100
# 4252         12557   Spain              lunch bag  black skull.        60
# 4253         12557   Spain              lunch bag red retrospot        70
# 4254         12557   Spain                  lunch bag cars blue       100
# 32454        12557   Spain    red 3 piece retrospot cutlery set       144
# 32455        12557   Spain    pink 3 piece polkadot cutlery set       360
# 32456        12557   Spain    blue 3 piece polkadot cutlery set       360
# 32457        12557   Spain   green 3 piece polkadot cutlery set       144
# 91155        12557   Spain               lunch bag suki design        150
# 91156        12557   Spain              lunch bag pink polkadot       150
# 91159        12557   Spain                  lunch bag cars blue       150
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
orders.loc[(orders.loc[:,'amount_spent'] == 0),['CustomerID','InvoiceNo','Description','amount_spent']]
# Out:
#         CustomerID  InvoiceNo                          Description  \
# 6914         12647     537197         round cake tin vintage green
# 22539        16560     539263         advent calendar gingham sack
# 25379        14911     539722             regency cakestand 3 tier
# 29080        13081     540372              paper bunting retrospot
# 29082        13081     540372               plasters in tin skulls
# 34494        15107     541109        organiser wood antique white
# 53788        17560     543599         fairy cakes notebook a6 size
# 85671        13239     547417  ceramic bowl with love heart design
# 92875        13113     548318   mini cake stand  hanging strawbery
# 97430        14410     548871          heart garland rustic padded
# 107192       12457     550188   childs breakfast set circus parade
# 128641       17667     553000                        party bunting
# 137127       12415     554037            set of 6 soldier skittles
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
orders.loc[(orders.loc[:,'Description'].str.contains('lunch bag')),['CustomerID','InvoiceNo','Description','amount_spent']]
# Out:
#         CustomerID  InvoiceNo                  Description  amount_spent
# 93           14688     536378      lunch bag red retrospot         16.50
# 172          17420     536385  lunch bag dolly girl design         16.50
# 354          15862     536401  lunch bag dolly girl design          1.65
# 359          15862     536401      lunch bag red retrospot          1.65
# 360          15862     536401   lunch bag spaceboy design           3.30
# ...            ...        ...                          ...           ...
# 397465       17001     581486    lunch bag alphabet design         16.50
# 397713       14446     581538      lunch bag  black skull.          1.65
# 397714       14446     581538      lunch bag red retrospot          1.65
# 397877       17581     581581  lunch bag red vintage doily         16.50
# 397880       13777     581583      lunch bag red retrospot         58.00
#
# [11556 rows x 4 columns]

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
orders.loc[((orders.loc[:,'Description'].str.contains('lunch bag')) & (orders.loc[:, 'year'] == 2011)),['CustomerID','Description','year']]
# Out:
#         CustomerID                  Description  year
# 26340        13319      lunch bag red retrospot  2011
# 26341        13319           lunch bag woodland  2011
# 26512        15039   lunch bag spaceboy design   2011
# 26513        15039           lunch bag woodland  2011
# 26860        16241      lunch bag pink polkadot  2011
# ...            ...                          ...   ...
# 397465       17001    lunch bag alphabet design  2011
# 397713       14446      lunch bag  black skull.  2011
# 397714       14446      lunch bag red retrospot  2011
# 397877       17581  lunch bag red vintage doily  2011
# 397880       13777      lunch bag red retrospot  2011
#
# [11234 rows x 3 columns]

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
spain['amount_spent'].value_counts().hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders.loc[(orders.loc[:,'month']== 8) ,['CustomerID','InvoiceNo','Description','month']]
# Out:
#         CustomerID  InvoiceNo                          Description  month
# 199475       17941     561904         6 ribbons elegant christmas       8
# 199476       17941     561904            scandinavian reds ribbons      8
# 199477       14947     561905      ivory hanging decoration  heart      8
# 199478       14947     561905     single heart zinc t-light holder      8
# 199479       14947     561905    hanging heart zinc t-light holder      8
# ...            ...        ...                                  ...    ...
# 226483       15856     565067       ceramic cherry cake money bank      8
# 226484       15856     565067  ceramic heart fairy cake money bank      8
# 226485       15856     565067                piggy bank retrospot       8
# 226486       15856     565067   ceramic strawberry cake money bank      8
# 226487       15856     565067                       funky diva pen      8
#
# [27013 rows x 4 columns]

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
orders.loc[(orders.loc[:,'month']== 8) ,['Country','month']].value_counts()
# Out:
# Country          month
# United Kingdom   8        23105
# Germany          8          795
# EIRE             8          593
# France           8          569
# Netherlands      8          280
# Switzerland      8          267
# Spain            8          252
# Belgium          8          194
# Israel           8          171
# Channel Islands  8          140
# Australia        8          107
# Italy            8           95
# Austria          8           88
# Norway           8           77
# Finland          8           61
# Malta            8           55
# Portugal         8           41
# Sweden           8           40
# Unspecified      8           23
# Iceland          8           22
# Poland           8           17
# Denmark          8           16
# Canada           8            5
# dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
order_money = orders.groupby('Country', as_index=False).agg({'amount_spent':np.mean})
order_money
# Out:
#                  Country  amount_spent
# 0              Australia    116.895620
# 1                Austria     25.624824
# 2                Bahrain     32.258824
# 3                Belgium     20.283772
# 4                 Brazil     35.737500
# 5                 Canada     24.280662
# 6        Channel Islands     27.340160
# 7                 Cyprus     22.134169
# 8         Czech Republic     33.069600
# 9                Denmark     49.882474
# 10                  EIRE     36.687745
# 11    European Community     21.670833
# 12               Finland     32.913985
# 13                France     25.056827
# 14               Germany     25.311562
# 15                Greece     32.831172
# 16               Iceland     23.681319
# 17                Israel     29.119718
# 18                 Italy     23.064960
# 19                 Japan    116.561900
# 20               Lebanon     37.641778
# 21             Lithuania     47.458857
# 22                 Malta     24.335625
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
orders.loc[(orders.loc[:,'UnitPrice'] == orders.loc[:,'UnitPrice'].max() ) ,['Description','UnitPrice']]
# Out:
#        Description  UnitPrice
# 118352     postage    8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
order_year2 = orders.groupby('year', as_index=False).agg({'amount_spent':np.mean})
order_year2
# Out:
#    year  amount_spent
# 0  2010     21.892733
# 1  2011     22.430074
