# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp.head(10)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      object
#  1   State        7 non-null      object
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
new_york = temp[temp['State'] == 'New York']
new_york
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
new_york = temp[temp['State'] == 'New York'].mean()
new_york
# Out:
# C:\Users\JoseV\AppData\Local\Temp\ipykernel_18392\968654302.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_york = temp[temp['State'] == 'New York'].mean()
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
heat_cities = temp[temp['Temperature'] > 15]
heat_cities
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp['City'][temp['Temperature'] > 15]
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp['City'][temp['Temperature'] > 15][temp['Temperature'] < 20]
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
temp.groupby('State').agg({'Temperature': np.mean})
# Out:
#              Temperature
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741

# %%
temp.groupby('State').agg({'Temperature': np.std})
# Out:
#              Temperature
# State
# Connecticut     1.964186
# New Jersey      1.571348
# New York        8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee = pd.read_csv('Employee.csv')

# %%
employee.head(10)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9 non-null      object
#  1   Department  9 non-null      object
#  2   Education   9 non-null      object
#  3   Gender      9 non-null      object
#  4   Title       9 non-null      object
#  5   Years       9 non-null      int64
#  6   Salary      9 non-null      int64
# dtypes: int64(2), object(5)
# memory usage: 632.0+ bytes

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
employee['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
employee[employee['Salary'] == 30]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[employee['Name'] == 'David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
# employee[employee['Salary'] == employee.loc[2,'Salary']]
employee.loc[2,'Salary']
# Out:
# 30

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee[employee['Title'] == 'associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee.iloc[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[(employee['Title'] == 'associate') & (employee['Salary'] > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
employee.loc[:,:].groupby('Years').mean()
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
employee.loc[:,:].groupby('Title').mean()
# Out:
#            Years     Salary
# Title
# VP          8.00  70.000000
# analyst     2.25  32.500000
# associate   4.00  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
employee.describe()
# Out:
#           Years     Salary
# count  9.000000   9.000000
# mean   4.111111  48.888889
# std    2.803767  16.541194
# min    1.000000  30.000000
# 25%    2.000000  35.000000
# 50%    3.000000  55.000000
# 75%    7.000000  60.000000
# max    8.000000  70.000000

# %%
# print first quartile here
employee['Salary'].quantile(0.25)
# Out:
# 35.0

# %%
# print third quartile here
employee['Salary'].quantile(0.75)
# Out:
# 60.0

# %%
employee['Salary'].plot.box()
# Out:
# <AxesSubplot:>

# %%
employee['Years'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
employee.loc[:,:].groupby('Gender').mean()
# Yes, which is awful
# Out:
#         Years  Salary
# Gender
# F         4.0    47.5
# M         4.2    50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
employee_stats = employee.describe()
employee_stats.loc[['mean','min','max'],:]
# Out:
#          Years     Salary
# mean  4.111111  48.888889
# min   1.000000  30.000000
# max   8.000000  70.000000

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
employee.head(10)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %%
# your answer here
a = employee[['Department','Salary']].groupby('Department').max()
b = employee[['Department','Salary']].groupby('Department').min()
c = a - b
c
# Out:
#             Salary
# Department
# HR              40
# IT              40
# Sales            0

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv('Orders.csv')

# %%
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  object
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  object
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  object
#  10  UnitPrice     397924 non-null  float64
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  object
#  13  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB

# %%
# your answer here
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
orders['amount_spent'].mean()
# Out:
# 22.394748504739596

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders['amount_spent'].max()
# Out:
# 168469.6

# %%
# your answer here
orders['amount_spent'].min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
spain_orders_df = orders[['CustomerID','Country']][orders['Country'] == 'Spain'].groupby('CustomerID').count()
spain_orders_df
# Out:
#             Country
# CustomerID
# 12354            58
# 12417            23
# 12421            45
# 12442            12
# 12445             4
# 12448            22
# 12450             8
# 12454            15
# 12455            48
# 12462            62
# 12484           346
# 12502           147
# 12507            22
# 12510            33
# 12538            21
# 12539           273
# 12540           478
# 12541            52
# 12544            19
# 12545            50
# 12546            69
# 12547             8
# 12548             5
# 12550            57
# 12551            10
# 12556           121
# 12557            33
# 12596            27
# 12597           206
# 17097           211

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
spain_customers = list(spain_orders_df['Country'])
len(spain_customers)
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
items_customers_df = orders[['Quantity','CustomerID']][orders['Quantity'] > 50].groupby('CustomerID').count()
items_customers_df
# Out:
#             Quantity
# CustomerID
# 12346              1
# 12347              1
# 12348             19
# 12355              2
# 12356              5
# ...              ...
# 18246              2
# 18248              1
# 18251             16
# 18260              1
# 18287              1
#
# [1301 rows x 1 columns]

# %%
items_customers = list(items_customers_df['Quantity'])
len(items_customers)
# Out:
# 1301

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
#orders[['InvoiceNo','Quantity','Country']][(orders['Quantity'] > 50) & (orders['Country'] == 'Spain')].groupby('InvoiceNo').count()
orders[['InvoiceNo','Quantity','Country']][(orders['Quantity'] > 50) & (orders['Country'] == 'Spain')]
# Out:
#         InvoiceNo  Quantity Country
# 4250       536944        70   Spain
# 4251       536944       100   Spain
# 4252       536944        60   Spain
# 4253       536944        70   Spain
# 4254       536944       100   Spain
# 32454      540785       144   Spain
# 32455      540785       360   Spain
# 32456      540785       360   Spain
# 32457      540785       144   Spain
# 91155      547972       150   Spain
# 91156      547972       150   Spain
# 91159      547972       150   Spain
# 174442     558871       100   Spain
# 174443     558871       100   Spain
# 174444     558871       100   Spain
# 174445     558871       100   Spain
# 174446     558871        72   Spain
# 174447     558871       360   Spain
# 174448     558871       360   Spain
# 174449     558871        72   Spain
# 197167     561669       128   Spain
# 197168     561669       144   Spain
# 197169     561669       128   Spain
# 197170     561669       128   Spain
# 197171     561669       128   Spain
# ...

# %% [markdown]
# #### Select all free orders

# %%
orders.loc[22539,:]
# Out:
# Unnamed: 0                             33576
# InvoiceNo                             539263
# StockCode                              22580
# year                                    2010
# month                                     12
# day                                        4
# hour                                      14
# Description     advent calendar gingham sack
# Quantity                                   4
# InvoiceDate              2010-12-16 14:36:00
# UnitPrice                                0.0
# CustomerID                             16560
# Country                       United Kingdom
# amount_spent                             0.0
# Name: 22539, dtype: object

# %%
# your answer here
orders[['UnitPrice','amount_spent']][orders['amount_spent'] == 0]
# Out:
#         UnitPrice  amount_spent
# 6914          0.0           0.0
# 22539         0.0           0.0
# 25379         0.0           0.0
# 29080         0.0           0.0
# 29082         0.0           0.0
# 34494         0.0           0.0
# 53788         0.0           0.0
# 85671         0.0           0.0
# 92875         0.0           0.0
# 97430         0.0           0.0
# 107192        0.0           0.0
# 128641        0.0           0.0
# 137127        0.0           0.0
# 194648        0.0           0.0
# 197173        0.0           0.0
# 199711        0.0           0.0
# 208950        0.0           0.0
# 223931        0.0           0.0
# 223932        0.0           0.0
# 223933        0.0           0.0
# 223934        0.0           0.0
# 256263        0.0           0.0
# 259399        0.0           0.0
# 273926        0.0           0.0
# 286507        0.0           0.0
# 307092        0.0           0.0
# 319882        0.0           0.0
# 320049        0.0           0.0
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
orders[['InvoiceNo','Description']][orders['Description'].str.contains('lunch bag')]
# Out:
#         InvoiceNo                  Description
# 93         536378      lunch bag red retrospot
# 172        536385  lunch bag dolly girl design
# 354        536401  lunch bag dolly girl design
# 359        536401      lunch bag red retrospot
# 360        536401   lunch bag spaceboy design
# ...           ...                          ...
# 397465     581486    lunch bag alphabet design
# 397713     581538      lunch bag  black skull.
# 397714     581538      lunch bag red retrospot
# 397877     581581  lunch bag red vintage doily
# 397880     581583      lunch bag red retrospot
#
# [11556 rows x 2 columns]

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
orders[['InvoiceNo','year','Description']][(orders['Description'].str.contains('lunch bag')) & (orders['year'] == 2011)]
# Out:
#         InvoiceNo  year                  Description
# 26340      540015  2011      lunch bag red retrospot
# 26341      540015  2011           lunch bag woodland
# 26512      540023  2011   lunch bag spaceboy design
# 26513      540023  2011           lunch bag woodland
# 26860      540098  2011      lunch bag pink polkadot
# ...           ...   ...                          ...
# 397465     581486  2011    lunch bag alphabet design
# 397713     581538  2011      lunch bag  black skull.
# 397714     581538  2011      lunch bag red retrospot
# 397877     581581  2011  lunch bag red vintage doily
# 397880     581583  2011      lunch bag red retrospot
#
# [11234 rows x 3 columns]

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders[['InvoiceNo','month']][orders['month'] == 8]
# Out:
#         InvoiceNo  month
# 199475     561904      8
# 199476     561904      8
# 199477     561905      8
# 199478     561905      8
# 199479     561905      8
# ...           ...    ...
# 226483     565067      8
# 226484     565067      8
# 226485     565067      8
# 226486     565067      8
# 226487     565067      8
#
# [27013 rows x 2 columns]

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
orders[['InvoiceNo','month','Country']][orders['month'] == 8].groupby('Country').count()
# Out:
#                  InvoiceNo  month
# Country
# Australia              107    107
# Austria                 88     88
# Belgium                194    194
# Canada                   5      5
# Channel Islands        140    140
# Denmark                 16     16
# EIRE                   593    593
# Finland                 61     61
# France                 569    569
# Germany                795    795
# Iceland                 22     22
# Israel                 171    171
# Italy                   95     95
# Malta                   55     55
# Netherlands            280    280
# Norway                  77     77
# Poland                  17     17
# Portugal                41     41
# Spain                  252    252
# Sweden                  40     40
# Switzerland            267    267
# United Kingdom       23105  23105
# Unspecified             23     23

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
orders[['Country','amount_spent']].groupby('Country').mean()
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
orders[['Description','UnitPrice']].sort_values('UnitPrice',ascending=False).head(1)
# Out:
#        Description  UnitPrice
# 118352     postage    8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
orders[['year','amount_spent']].groupby('year').mean()
# Out:
#       amount_spent
# year
# 2010     21.892733
# 2011     22.430074
