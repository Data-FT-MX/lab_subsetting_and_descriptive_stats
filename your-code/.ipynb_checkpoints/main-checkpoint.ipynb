# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# !pip install matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Program Files\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
temp = pd.read_csv('C:/Users/Pablo Gonzalez Uzeta/Desktop/Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         7 non-null      object
#  1   State        7 non-null      object
#  2   Temperature  7 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# #### Select the rows where state is New York

# %%
temp[temp['State'].str.match('New York')]
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
temp[temp['State'].str.match('New York')].mean()
# Out:
# C:\Users\PABLOG~1\AppData\Local\Temp/ipykernel_13352/3805283455.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   temp[temp['State'].str.match('New York')].mean()
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
temp.loc[(temp.loc[:,'Temperature'] > 15) , ['City','State','Temperature']]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
temp.loc[(temp.loc[:,'Temperature'] > 15) , ['City','Temperature']]
# Out:
#        City  Temperature
# 0       NYC    19.444444
# 3  Hartford    17.222222
# 5    Treton    22.222222
# 6    Newark    20.000000

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp[(temp.loc[:,'Temperature'] > 15) & (temp.loc[:,'Temperature'] < 20)]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
NY = temp[(temp['State'] == 'New York')]
CN = temp[(temp['State'] == 'Connecticut')]
NJ = temp[(temp['State'] == 'New Jersey')]
print('Mean NY', NY['Temperature'].mean())
print('Mean CN',CN['Temperature'].mean())
print('Mean NJ',NJ['Temperature'].mean())
print('Dev NY',NY['Temperature'].std())
print('Dev CN',CN['Temperature'].std())
print('Dev NJ',NJ['Temperature'].std())
# Out:
# Mean NY 10.74074074074074
# Mean CN 15.833333333333332
# Mean NJ 21.11111111111111
# Dev NY 8.133404168888054
# Dev CN 1.9641855032959645
# Dev NJ 1.5713484026367717

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
employee = pd.read_csv('C:/Users/Pablo Gonzalez Uzeta/Desktop/Employee.csv')

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
employee.head()
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55

# %%
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9 non-null      object
#  1   Department  9 non-null      object
#  2   Education   9 non-null      object
#  3   Gender      9 non-null      object
#  4   Title       9 non-null      object
#  5   Years       9 non-null      int64
#  6   Salary      9 non-null      int64
# dtypes: int64(2), object(5)
# memory usage: 632.0+ bytes

# %% [markdown]
# #### What's the average salary in this company?

# %%
employee['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
employee['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
employee['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
sal = employee.loc[:, ['Name', 'Salary'] ]

sal.sort_values('Salary', ascending=True).head(1)
# Out:
#     Name  Salary
# 1  Maria      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
employee[employee['Name'].str.match('David')]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
employee.loc[employee.loc[:,'Name'].str.match('David'),['Salary']]
# Out:
#    Salary
# 2      30

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
print(employee['Title'])
# Out:
# 0      analyst
# 1      analyst
# 2      analyst
# 3      analyst
# 4    associate
# 5    associate
# 6           VP
# 7    associate
# 8           VP
# Name: Title, dtype: object

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
employee.iloc[0:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
employee.loc[(employee.loc[:,'Salary'] > 55) , ['Title','Name']]
# Out:
#        Title    Name
# 6         VP  Carlos
# 7  associate   Pedro
# 8         VP     Ana

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
employee.groupby(['Years']).mean()
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
employee.groupby(['Title']).mean()
# Out:
#            Years     Salary
# Title
# VP          8.00  70.000000
# analyst     2.25  32.500000
# associate   4.00  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
employee.describe()
# Out:
#           Years     Salary
# count  9.000000   9.000000
# mean   4.111111  48.888889
# std    2.803767  16.541194
# min    1.000000  30.000000
# 25%    2.000000  35.000000
# 50%    3.000000  55.000000
# 75%    7.000000  60.000000
# max    8.000000  70.000000

# %%
employee.quantile(0.25)
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
employee.quantile(0.75)
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
employee.groupby(['Gender']).mean()
# Out:
#         Years  Salary
# Gender
# F         4.0    47.5
# M         4.2    50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
print(employee.groupby(['Department']).mean())
print(employee.groupby(['Department']).min())
print(employee.groupby(['Department']).max())
# Out:
#                Years  Salary
# Department
# HR          4.666667   45.00
# IT          4.500000   48.75
# Sales       2.500000   55.00
#               Name Education Gender      Title  Years  Salary
# Department
# HR             Ana  Bachelor      F         VP      2      30
# IT          Carlos  Bachelor      F         VP      1      30
# Sales          Eva  Bachelor      F  associate      2      55
#               Name Education Gender      Title  Years  Salary
# Department
# HR           Sonia    Master      M    analyst      8      70
# IT           Pedro       Phd      M  associate      8      70
# Sales       Samuel    Master      M  associate      3      55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
orders = pd.read_csv('C:/Users/Pablo Gonzalez Uzeta/Desktop/Orders.csv')

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  object
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  object
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  object
#  10  UnitPrice     397924 non-null  float64
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  object
#  13  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
orders['UnitPrice'].mean()
# Out:
# 3.1161744805540756

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
orders['UnitPrice'].min()
# Out:
# 0.0

# %%
orders['UnitPrice'].max()
# Out:
# 8142.75

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
val = orders.loc[orders.loc[:,'Country'].str.match('Spain') , ['CustomerID','Country']]
val
# Out:
#         CustomerID Country
# 4250         12557   Spain
# 4251         12557   Spain
# 4252         12557   Spain
# 4253         12557   Spain
# 4254         12557   Spain
# ...            ...     ...
# 394733       17097   Spain
# 394734       17097   Spain
# 394735       17097   Spain
# 394736       17097   Spain
# 394737       17097   Spain
#
# [2485 rows x 2 columns]

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
val.value_counts()
# Out:
# CustomerID  Country
# 12540       Spain      478
# 12484       Spain      346
# 12539       Spain      273
# 17097       Spain      211
# 12597       Spain      206
# 12502       Spain      147
# 12556       Spain      121
# 12546       Spain       69
# 12462       Spain       62
# 12354       Spain       58
# 12550       Spain       57
# 12541       Spain       52
# 12545       Spain       50
# 12455       Spain       48
# 12421       Spain       45
# 12510       Spain       33
# 12557       Spain       33
# 12596       Spain       27
# 12417       Spain       23
# 12507       Spain       22
# 12448       Spain       22
# 12538       Spain       21
# 12544       Spain       19
# 12454       Spain       15
# 12442       Spain       12
# 12551       Spain       10
# 12450       Spain        8
# 12547       Spain        8
# 12548       Spain        5
# 12445       Spain        4
# dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
orders.loc[(orders.loc[:,'Quantity'] > 55) , ['Quantity','CustomerID']]
# Out:
#         Quantity  CustomerID
# 46            80       13748
# 83            64       15291
# 96           120       14688
# 102           96       14688
# 174          100       16029
# ...          ...         ...
# 397720       144       18102
# 397721        84       16626
# 397729       144       16626
# 397761        96       15311
# 397882        72       13777
#
# [11564 rows x 2 columns]

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
orders.loc[(orders.loc[:,'Quantity'] > 50) & (orders.loc[:,'Country'].str.match('Spain')),['Quantity','CustomerID','Country']]
# Out:
#         Quantity  CustomerID Country
# 4250          70       12557   Spain
# 4251         100       12557   Spain
# 4252          60       12557   Spain
# 4253          70       12557   Spain
# 4254         100       12557   Spain
# 32454        144       12557   Spain
# 32455        360       12557   Spain
# 32456        360       12557   Spain
# 32457        144       12557   Spain
# 91155        150       12557   Spain
# 91156        150       12557   Spain
# 91159        150       12557   Spain
# 174442       100       12557   Spain
# 174443       100       12557   Spain
# 174444       100       12557   Spain
# 174445       100       12557   Spain
# 174446        72       12557   Spain
# 174447       360       12557   Spain
# 174448       360       12557   Spain
# 174449        72       12557   Spain
# 197167       128       12507   Spain
# 197168       144       12507   Spain
# 197169       128       12507   Spain
# 197170       128       12507   Spain
# ...

# %% [markdown]
# #### Select all free orders

# %%
orders.loc[orders['amount_spent'] == 0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
orders.loc[:,'Description'].str.match('lunch bag')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 397919    False
# 397920    False
# 397921    False
# 397922    False
# 397923    False
# Name: Description, Length: 397924, dtype: bool

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
orders.loc[(orders.loc[:,'year'] == 2011) & (orders.loc[:,'Description'].str.match('lunch bag'))]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
orders.loc[orders.loc[:,'Country'].str.match('Spain')].hist()
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'InvoiceNo'}>,
#         <AxesSubplot:title={'center':'year'}>],
#        [<AxesSubplot:title={'center':'month'}>,
#         <AxesSubplot:title={'center':'day'}>,
#         <AxesSubplot:title={'center':'hour'}>],
#        [<AxesSubplot:title={'center':'Quantity'}>,
#         <AxesSubplot:title={'center':'UnitPrice'}>,
#         <AxesSubplot:title={'center':'CustomerID'}>],
#        [<AxesSubplot:title={'center':'amount_spent'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# #### Select all orders made in the month of August

# %%
orders.loc[orders['month'] == 8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
orders.loc[(orders['month'] == 8),['Country']].value_counts
# Out:
# <bound method DataFrame.value_counts of                Country
# 199475  United Kingdom
# 199476  United Kingdom
# 199477  United Kingdom
# 199478  United Kingdom
# 199479  United Kingdom
# ...                ...
# 226483  United Kingdom
# 226484  United Kingdom
# 226485  United Kingdom
# 226486  United Kingdom
# 226487  United Kingdom
#
# [27013 rows x 1 columns]>

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
orders.groupby(['Country']).mean()
# Out:
#                          Unnamed: 0      InvoiceNo         year      month  \
# Country
# Australia             224857.287764  556217.951055  2010.972996   6.062447
# Austria               297239.085427  562367.633166  2010.979899   7.623116
# Bahrain               184964.000000  552790.411765  2011.000000   5.000000
# Belgium               276657.968981  560543.014279  2010.953225   7.404727
# Brazil                157314.500000  550201.000000  2011.000000   4.000000
# Canada                240605.867550  557964.476821  2011.000000   6.377483
# Channel Islands       255107.524064  558786.728610  2010.977273   6.791444
# Cyprus                236759.193811  556821.771987  2010.864821   7.311075
# Czech Republic        215563.200000  555053.600000  2011.000000   5.200000
# Denmark               299546.760526  562479.600000  2010.947368   7.905263
# EIRE                  289810.162476  561673.445012  2010.953855   7.726996
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
orders['UnitPrice'].max()
# Out:
# 8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
orders.groupby(['year']).mean()
# Out:
#          Unnamed: 0      InvoiceNo      month       day       hour   Quantity  \
# year
# 2010   19884.040482  538009.305122  12.000000  3.745528  12.897630  11.937309
# 2011  296660.861310  562207.976246   7.303803  3.605338  12.716328  13.098138
#
#       UnitPrice    CustomerID  amount_spent
# year
# 2010   3.132095  15529.088417     21.892733
# 2011   3.115054  15277.794830     22.430074
